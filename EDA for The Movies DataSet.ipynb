# %% [markdown]
# # EDA for Movies Metadata

# %% [markdown]
# ## Import libraries

# %%
#Import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# I downloaded the keywords.csv and movieMetadata.csv from the movies dataset(). Then I only saved the data of movies in MovieLen-1M DataSet.
# Also, to get the imdb_id and tmdb_id of the movies, I downloaded the links.csv from MovieLen-20M DataSet.

# %% [markdown]
# ## Keywords Data

# %% [markdown]
# This file includes the keywords of movies.

# %%
keywordsDF = pd.read_csv('The Movies Dataset/keywords.csv', index_col = 0)

# %%
keywordsDF
# Out:
#          id                                           keywords
# 0       862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1      8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2     15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3     31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4     11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# ...     ...                                                ...
# 3823   1597  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
# 3824    641  [{'id': 1803, 'name': 'drug addiction'}, {'id'...
# 3825  10687  [{'id': 10183, 'name': 'independent film'}, {'...
# 3826  63956                                                 []
# 3827   6521  [{'id': 6078, 'name': 'politics'}, {'id': 9937...
#
# [3828 rows x 2 columns]

# %%
keywordsDF.loc[0]['keywords']
# Out:
# "[{'id': 931, 'name': 'jealousy'}, {'id': 4290, 'name': 'toy'}, {'id': 5202, 'name': 'boy'}, {'id': 6054, 'name': 'friendship'}, {'id': 9713, 'name': 'friends'}, {'id': 9823, 'name': 'rivalry'}, {'id': 165503, 'name': 'boy next door'}, {'id': 170722, 'name': 'new toy'}, {'id': 187065, 'name': 'toy comes to life'}]"

# %% [markdown]
# ## Links Data

# %% [markdown]
# This file includes the MovieID, IMDBID, TMDBID of movies.

# %%
linkDF = pd.read_csv('The Movies Dataset/links.csv', index_col = 0)

# %%
linkDF
# Out:
#       movieId  imdbId   tmdbId
# 0           1  114709    862.0
# 1           2  113497   8844.0
# 2           3  113228  15602.0
# 3           4  114885  31357.0
# 4           5  113041  11862.0
# ...       ...     ...      ...
# 3854     3948  212338   1597.0
# 3855     3949  180093    641.0
# 3856     3950  170691  10687.0
# 3857     3951  202641  63956.0
# 3858     3952  208874   6521.0
#
# [3859 rows x 3 columns]

# %%
linkDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3859 entries, 0 to 3858
# Data columns (total 3 columns):
# movieId    3859 non-null int64
# imdbId     3859 non-null int64
# tmdbId     3823 non-null float64
# dtypes: float64(1), int64(2)
# memory usage: 120.6 KB

# %% [markdown]
# ## Movies Metadata

# %% [markdown]
# This file includes many attributes of movies.

# %%
moviesMetadataDF = pd.read_csv("The Movies Dataset/moviesMetadata.csv", index_col = 0)

# %%
moviesMetadataDF
# Out:
#       adult                              belongs_to_collection    budget  \
# 0     False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1     False                                                NaN  65000000
# 2     False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3     False                                                NaN  16000000
# 4     False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...     ...                                                ...       ...
# 3823  False  {'id': 51509, 'name': 'Meet the Parents Collec...  55000000
# 3824  False                                                NaN   4500000
# 3825  False                                                NaN  10000000
# 3826  False                                                NaN         0
# 3827  False                                                NaN   9000000
#
#                                   genres  \
# 0      ['Animation', 'Comedy', 'Family']
# ...

# %%
moviesMetadataDF.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %% [markdown]
# For contented-based algorithms, I chose the following columns: 'genres', 'id',  'overview', 'tagline', 'title'

# %%
moviesMetadataDF = moviesMetadataDF[['genres', 'id', 'overview', 'tagline', 'title']]

# %%
moviesMetadataDF
# Out:
#                                   genres     id  \
# 0      ['Animation', 'Comedy', 'Family']    862
# 1     ['Adventure', 'Fantasy', 'Family']   8844
# 2                  ['Romance', 'Comedy']  15602
# 3         ['Comedy', 'Drama', 'Romance']  31357
# 4                             ['Comedy']  11862
# ...                                  ...    ...
# 3823               ['Comedy', 'Romance']   1597
# 3824                  ['Crime', 'Drama']    641
# 3825                    ['Drama', 'War']  10687
# 3826                ['Drama', 'Romance']  63956
# 3827               ['Drama', 'Thriller']   6521
#
#                                                overview  \
# 0     Led by Woody, Andy's toys live happily in his ...
# 1     When siblings Judy and Peter discover an encha...
# 2     A family wedding reignites the ancient feud be...
# 3     Cheated on, mistreated and stepped on, the wom...
# 4     Just when George Banks has recovered from his ...
# ...

# %%
creditsDF = pd.read_csv("The Movies Dataset/credits.csv")

# %%
creditsDF
# Out:
#       Unnamed: 0                                               cast  \
# 0              0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1              1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2              2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3              3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4              4  [{'cast_id': 1, 'character': 'George Banks', '...
# ...          ...                                                ...
# 3823        3823  [{'cast_id': 1, 'character': 'Gaylord "Greg" F...
# 3824        3824  [{'cast_id': 29, 'character': 'Sara Goldfarb',...
# 3825        3825  [{'cast_id': 1, 'character': 'Pvt. Roland Bozz...
# 3826        3826  [{'cast_id': 1, 'character': 'Buddy Visalo', '...
# 3827        3827  [{'cast_id': 1, 'character': 'Sheldon Runyon',...
#
#                                                    crew     id
# 0     [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# ...

# %%
creditsDF.loc[0]['cast']
# Out:
# "[{'cast_id': 14, 'character': 'Woody (voice)', 'credit_id': '52fe4284c3a36847f8024f95', 'gender': 2, 'id': 31, 'name': 'Tom Hanks', 'order': 0, 'profile_path': '/pQFoyx7rp09CJTAb932F2g8Nlho.jpg'}, {'cast_id': 15, 'character': 'Buzz Lightyear (voice)', 'credit_id': '52fe4284c3a36847f8024f99', 'gender': 2, 'id': 12898, 'name': 'Tim Allen', 'order': 1, 'profile_path': '/uX2xVf6pMmPepxnvFWyBtjexzgY.jpg'}, {'cast_id': 16, 'character': 'Mr. Potato Head (voice)', 'credit_id': '52fe4284c3a36847f8024f9d', 'gender': 2, 'id': 7167, 'name': 'Don Rickles', 'order': 2, 'profile_path': '/h5BcaDMPRVLHLDzbQavec4xfSdt.jpg'}, {'cast_id': 17, 'character': 'Slinky Dog (voice)', 'credit_id': '52fe4284c3a36847f8024fa1', 'gender': 2, 'id': 12899, 'name': 'Jim Varney', 'order': 3, 'profile_path': '/eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg'}, {'cast_id': 18, 'character': 'Rex (voice)', 'credit_id': '52fe4284c3a36847f8024fa5', 'gender': 2, 'id': 12900, 'name': 'Wallace Shawn', 'order': 4, 'profile_path': '/oGE6JqPP2xH
# ...
